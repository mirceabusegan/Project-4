# %%
import yfinance as yf
import pandas as pd
import os

# %%
ticker = 'AAPL'
stock = yf.Ticker(ticker)
stock = stock.history(period="max")
stock.to_csv(ticker +'.csv')

# %%
stock.index = pd.to_datetime(stock.index)
stock.head(10)
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 1980-12-12 00:00:00-05:00  0.098834  0.099264  0.098834  0.098834  469033600
# 1980-12-15 00:00:00-05:00  0.094108  0.094108  0.093678  0.093678  175884800
# 1980-12-16 00:00:00-05:00  0.087232  0.087232  0.086802  0.086802  105728000
# 1980-12-17 00:00:00-05:00  0.088951  0.089381  0.088951  0.088951   86441600
# 1980-12-18 00:00:00-05:00  0.091530  0.091959  0.091530  0.091530   73449600
# 1980-12-19 00:00:00-05:00  0.097116  0.097545  0.097116  0.097116   48630400
# 1980-12-22 00:00:00-05:00  0.101842  0.102273  0.101842  0.101842   37363200
# 1980-12-23 00:00:00-05:00  0.106140  0.106570  0.106140  0.106140   46950400
# 1980-12-24 00:00:00-05:00  0.111726  0.112156  0.111726  0.111726   48003200
# 1980-12-26 00:00:00-05:00  0.122039  0.122469  0.122039  0.122039   55574400
#
#                            Dividends  Stock Splits
# Date
# 1980-12-12 00:00:00-05:00        0.0           0.0
# 1980-12-15 00:00:00-05:00        0.0           0.0
# 1980-12-16 00:00:00-05:00        0.0           0.0
# 1980-12-17 00:00:00-05:00        0.0           0.0
# 1980-12-18 00:00:00-05:00        0.0           0.0
# 1980-12-19 00:00:00-05:00        0.0           0.0
# 1980-12-22 00:00:00-05:00        0.0           0.0
# 1980-12-23 00:00:00-05:00        0.0           0.0
# 1980-12-24 00:00:00-05:00        0.0           0.0
# 1980-12-26 00:00:00-05:00        0.0           0.0

# %%
stock.plot.line(y='High', use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
del stock['Dividends']
del stock['Stock Splits']

# %%
stock["Tomorrow"] = stock["Close"].shift(-1)

# %%
stock["Target"] = (stock["Tomorrow"] > stock["Close"]).astype(int)

# %%
stock = stock.loc["2000-01-01":].copy()

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=200, min_samples_split=200, random_state=1)

train = stock.iloc[:-200]
test = stock.iloc[-200:]

predictors = ["Close", "Volume", "Open", "High", "Low"]
model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=200, n_estimators=200, random_state=1)

# %%
from sklearn.metrics import precision_score

preds = model.predict(test[predictors])
preds = pd.Series(preds, index=test.index)
precision_score(test["Target"], preds)
# Out:
# 0.5641025641025641

# %%
combined = pd.concat([test["Target"], preds], axis=1)
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
def backtest(data, model, predictors, start=2500, step=250):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    
    return pd.concat(all_predictions)

# %%
predictions = backtest(stock, model, predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0    2369
# 1    1398
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5271816881258942

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.530396
# 0    0.469604
# Name: count, dtype: float64

# %%
ranges = [2,5,60,250,1000]
new_predictors = []

for range in ranges:
    rolling_averages = stock.rolling(range).mean()
    
    ratio_column = f"Close_Ratio_{range}"
    stock[ratio_column] = stock["Close"] / rolling_averages["Close"]
    
    trend_column = f"Trend_{range}"
    stock[trend_column] = stock.shift(1).rolling(range).sum()["Target"]
    
    new_predictors+= [ratio_column, trend_column]

# %%
stock = stock.dropna(subset=stock.columns[stock.columns != "Tomorrow"])
stock.head(10)
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 2003-12-26 00:00:00-05:00  0.306539  0.314975  0.306388  0.313016  103695200
# 2003-12-29 00:00:00-05:00  0.314975  0.318740  0.314221  0.318590  233458400
# 2003-12-30 00:00:00-05:00  0.319041  0.323862  0.318590  0.320548  204853600
# 2003-12-31 00:00:00-05:00  0.321602  0.324314  0.319041  0.321904  174451200
# 2004-01-02 00:00:00-05:00  0.324615  0.327628  0.319041  0.320548  144642400
# 2004-01-05 00:00:00-05:00  0.322657  0.337268  0.322657  0.333954  395018400
# 2004-01-06 00:00:00-05:00  0.335159  0.337720  0.327026  0.332749  509348000
# 2004-01-07 00:00:00-05:00  0.332900  0.343897  0.330339  0.340281  586874400
# 2004-01-08 00:00:00-05:00  0.344047  0.357453  0.341185  0.351880  460303200
# 2004-01-09 00:00:00-05:00  0.349921  0.363479  0.343293  0.346457  427459200
#
#                            Tomorrow  Target  Close_Ratio_2  Trend_2  \
# Date
# 2003-12-26 00:00:00-05:00  0.318590       1       1.008982      2.0
# 2003-12-29 00:00:00-05:00  0.320548       1       1.008825      2.0
# 2003-12-30 00:00:00-05:00  0.321904       1       1.003063      2.0
# 2003-12-31 00:00:00-05:00  0.320548       0       1.002110      2.0
# 2004-01-02 00:00:00-05:00  0.333954       1       0.997890      1.0
# 2004-01-05 00:00:00-05:00  0.332749       0       1.020484      1.0
# 2004-01-06 00:00:00-05:00  0.340281       1       0.998192      1.0
# 2004-01-07 00:00:00-05:00  0.351880       1       1.011191      1.0
# 2004-01-08 00:00:00-05:00  0.346457       0       1.016757      2.0
# 2004-01-09 00:00:00-05:00  0.357453       1       0.992234      1.0
#
#                            Close_Ratio_5  Trend_5  Close_Ratio_60  Trend_60  \
# Date
# 2003-12-26 00:00:00-05:00       1.033316      3.0        0.951842      28.0
# 2003-12-29 00:00:00-05:00       1.036766      4.0        0.968363      29.0
# 2003-12-30 00:00:00-05:00       1.028715      4.0        0.974619      29.0
# 2003-12-31 00:00:00-05:00       1.017716      5.0        0.979429      29.0
# 2004-01-02 00:00:00-05:00       1.005101      4.0        0.976752      28.0
# 2004-01-05 00:00:00-05:00       1.033567      4.0        1.018296      29.0
# 2004-01-06 00:00:00-05:00       1.020888      3.0        1.015678      28.0
# 2004-01-07 00:00:00-05:00       1.031507      3.0        1.039537      28.0
# 2004-01-08 00:00:00-05:00       1.047628      3.0        1.075788      28.0
# 2004-01-09 00:00:00-05:00       1.015810      3.0        1.060469      27.0
#
#                            Close_Ratio_250  Trend_250  Close_Ratio_1000  \
# Date
# 2003-12-26 00:00:00-05:00         1.123531      129.0          0.801992
# 2003-12-29 00:00:00-05:00         1.141855      129.0          0.817223
# 2003-12-30 00:00:00-05:00         1.147266      129.0          0.823222
# 2003-12-31 00:00:00-05:00         1.150513      129.0          0.827540
# 2004-01-02 00:00:00-05:00         1.144096      129.0          0.824965
# 2004-01-05 00:00:00-05:00         1.190073      130.0          0.860359
# 2004-01-06 00:00:00-05:00         1.183860      130.0          0.858062
# 2004-01-07 00:00:00-05:00         1.208609      130.0          0.878201
# 2004-01-08 00:00:00-05:00         1.247499      130.0          0.909019
# 2004-01-09 00:00:00-05:00         1.226080      130.0          0.895958
#
#                            Trend_1000
# Date
# 2003-12-26 00:00:00-05:00       471.0
# 2003-12-29 00:00:00-05:00       472.0
# 2003-12-30 00:00:00-05:00       472.0
# 2003-12-31 00:00:00-05:00       473.0
# 2004-01-02 00:00:00-05:00       472.0
# 2004-01-05 00:00:00-05:00       473.0
# 2004-01-06 00:00:00-05:00       473.0
# 2004-01-07 00:00:00-05:00       474.0
# 2004-01-08 00:00:00-05:00       474.0
# 2004-01-09 00:00:00-05:00       473.0
