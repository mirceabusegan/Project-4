# %%
# The algo predicts if tomorrow the stock will go up or down from today's closing price
#dependencies 
import yfinance as yf
import pandas as pd
import os
import finta

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score

# %%
# Create a DataFrame for the model accuracy by ticker
model_accuracy = pd.DataFrame(columns = ['Ticker', 'Model 1 Accuracy', 'Prediction Tomorrow', 'Model 2 Accuracy', 'Prediction Tomorrow'])
#model_accuracy.to_csv('accuracy.csv', index=False)

# %%
#getting the data from Yahoo Finance
ticker = 'TSLA'
stock = yf.Ticker(ticker)
stock = stock.history(period="max")

# %%
stock.index = pd.to_datetime(stock.index)
stock.head(10)
# Out:
#                                Open      High       Low     Close     Volume  \
# Date
# 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667  281494500
# 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667  257806500
# 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000  123282000
# 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000   77097000
# 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000  103003500
# 2010-07-07 00:00:00-04:00  1.093333  1.108667  0.998667  1.053333  103825500
# 2010-07-08 00:00:00-04:00  1.076000  1.168000  1.038000  1.164000  115671000
# 2010-07-09 00:00:00-04:00  1.172000  1.193333  1.103333  1.160000   60759000
# 2010-07-12 00:00:00-04:00  1.196667  1.204667  1.133333  1.136667   33037500
# 2010-07-13 00:00:00-04:00  1.159333  1.242667  1.126667  1.209333   40201500
#
#                            Dividends  Stock Splits
# Date
# 2010-06-29 00:00:00-04:00        0.0           0.0
# 2010-06-30 00:00:00-04:00        0.0           0.0
# 2010-07-01 00:00:00-04:00        0.0           0.0
# 2010-07-02 00:00:00-04:00        0.0           0.0
# 2010-07-06 00:00:00-04:00        0.0           0.0
# 2010-07-07 00:00:00-04:00        0.0           0.0
# 2010-07-08 00:00:00-04:00        0.0           0.0
# 2010-07-09 00:00:00-04:00        0.0           0.0
# 2010-07-12 00:00:00-04:00        0.0           0.0
# 2010-07-13 00:00:00-04:00        0.0           0.0

# %%
#visualizing the stock chart
stock.plot.line(y='Close', use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
#Cleaning the data: deleting the 2 columns we don't need
del stock['Dividends']
del stock['Stock Splits']

# %%
#Setting up the target (Tomorrow)
#creating a new column "Tomorrow" from the previous day's "Close" price 
stock["Tomorrow"] = stock["Close"].shift(-1)

# %%
#Checking if "Tomorrow" price is greater than today's ("Close") price
stock["Target"] = (stock["Tomorrow"] > stock["Close"]).astype(int) #returns 0 for going DOWN and 1 for going UP
stock
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2010-06-29 00:00:00-04:00    1.266667    1.666667    1.169333    1.592667
# 2010-06-30 00:00:00-04:00    1.719333    2.028000    1.553333    1.588667
# 2010-07-01 00:00:00-04:00    1.666667    1.728000    1.351333    1.464000
# 2010-07-02 00:00:00-04:00    1.533333    1.540000    1.247333    1.280000
# 2010-07-06 00:00:00-04:00    1.333333    1.333333    1.055333    1.074000
# ...                               ...         ...         ...         ...
# 2024-12-02 00:00:00-05:00  352.380005  360.000000  351.149994  357.089996
# 2024-12-03 00:00:00-05:00  351.799988  355.690002  348.200012  351.420013
# 2024-12-04 00:00:00-05:00  353.000000  358.100006  348.600006  357.929993
# 2024-12-05 00:00:00-05:00  359.869995  375.429993  359.500000  369.489990
# 2024-12-06 00:00:00-05:00  377.269989  389.489990  370.799988  389.220001
#
#                               Volume    Tomorrow  Target
# Date
# 2010-06-29 00:00:00-04:00  281494500    1.588667       0
# 2010-06-30 00:00:00-04:00  257806500    1.464000       0
# 2010-07-01 00:00:00-04:00  123282000    1.280000       0
# 2010-07-02 00:00:00-04:00   77097000    1.074000       0
# 2010-07-06 00:00:00-04:00  103003500    1.053333       0
# ...                              ...         ...     ...
# 2024-12-02 00:00:00-05:00   77986500  351.420013       0
# 2024-12-03 00:00:00-05:00   58267200  357.929993       1
# 2024-12-04 00:00:00-05:00   50810900  369.489990       1
# 2024-12-05 00:00:00-05:00   81403600  389.220001       1
# 2024-12-06 00:00:00-05:00   78455915         NaN       0
#
# [3636 rows x 7 columns]

# %%
#eliminating data that is too old to be relevant (before 2000)
stock = stock.loc["1990-01-01":].copy()
stock
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2010-06-29 00:00:00-04:00    1.266667    1.666667    1.169333    1.592667
# 2010-06-30 00:00:00-04:00    1.719333    2.028000    1.553333    1.588667
# 2010-07-01 00:00:00-04:00    1.666667    1.728000    1.351333    1.464000
# 2010-07-02 00:00:00-04:00    1.533333    1.540000    1.247333    1.280000
# 2010-07-06 00:00:00-04:00    1.333333    1.333333    1.055333    1.074000
# ...                               ...         ...         ...         ...
# 2024-12-02 00:00:00-05:00  352.380005  360.000000  351.149994  357.089996
# 2024-12-03 00:00:00-05:00  351.799988  355.690002  348.200012  351.420013
# 2024-12-04 00:00:00-05:00  353.000000  358.100006  348.600006  357.929993
# 2024-12-05 00:00:00-05:00  359.869995  375.429993  359.500000  369.489990
# 2024-12-06 00:00:00-05:00  377.269989  389.489990  370.799988  389.220001
#
#                               Volume    Tomorrow  Target
# Date
# 2010-06-29 00:00:00-04:00  281494500    1.588667       0
# 2010-06-30 00:00:00-04:00  257806500    1.464000       0
# 2010-07-01 00:00:00-04:00  123282000    1.280000       0
# 2010-07-02 00:00:00-04:00   77097000    1.074000       0
# 2010-07-06 00:00:00-04:00  103003500    1.053333       0
# ...                              ...         ...     ...
# 2024-12-02 00:00:00-05:00   77986500  351.420013       0
# 2024-12-03 00:00:00-05:00   58267200  357.929993       1
# 2024-12-04 00:00:00-05:00   50810900  369.489990       1
# 2024-12-05 00:00:00-05:00   81403600  389.220001       1
# 2024-12-06 00:00:00-05:00   78455915         NaN       0
#
# [3636 rows x 7 columns]

# %%
# Training the model 

model = RandomForestClassifier(n_estimators=400, min_samples_split=300, random_state=1)

#spliting the dataset in training and testing subsets
train = stock.iloc[:-300]
test = stock.iloc[-300:]

predictors = ["Close", "Volume", "Open", "High", "Low"]
model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=300, n_estimators=400, random_state=1)

# %%
#measuring the model's accuracy
preds = model.predict(test[predictors])
preds = pd.Series(preds, index=test.index)

# %%
#store the accuracy for the initial model for later use
M1A = precision_score(test["Target"], preds)
precision_score(test["Target"], preds)
# Out:
# 0.5157232704402516

# %%
#store the prediction for tomorrow. Will be used later 
last_prediction_M1 = preds.iloc[-1]
last_prediction_M1
# Out:
# 0

# %%
#Ploting the predictions vs the actual results
preds.name = "Prediction"
combined = pd.concat([test["Target"], preds], axis=1)
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#BACK TESTING 
#Creating a function that returns a data frame with the target and predictions for the test data
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined
combined
# Out:
#                            Target  Prediction
# Date
# 2023-09-29 00:00:00-04:00       1           1
# 2023-10-02 00:00:00-04:00       0           0
# 2023-10-03 00:00:00-04:00       1           1
# 2023-10-04 00:00:00-04:00       0           1
# 2023-10-05 00:00:00-04:00       1           0
# ...                           ...         ...
# 2024-12-02 00:00:00-05:00       0           1
# 2024-12-03 00:00:00-05:00       1           1
# 2024-12-04 00:00:00-05:00       1           1
# 2024-12-05 00:00:00-05:00       1           0
# 2024-12-06 00:00:00-05:00       0           0
#
# [300 rows x 2 columns]

# %%
#creating a function that takes the data from past 10 years, trains the model, than it keeps adding 1 year (step=250)

def backtest(data, model, predictors, start=2500, step=250):
    all_predictions = []
    
    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
        
    return pd.concat(all_predictions)

# %%
#back testing using the 2 functions that were just defined
predictions = backtest(stock, model, predictors)

# %%
#Checking the count of the 2 types of predictions
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 1    592
# 0    544
# Name: count, dtype: int64

# %%
#Checking the accuracy
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5304054054054054

# %%
#Checking the actual market (0=went down, 1=went up)
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.529049
# 0    0.470951
# Name: count, dtype: float64

# %%
stock
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2010-06-29 00:00:00-04:00    1.266667    1.666667    1.169333    1.592667
# 2010-06-30 00:00:00-04:00    1.719333    2.028000    1.553333    1.588667
# 2010-07-01 00:00:00-04:00    1.666667    1.728000    1.351333    1.464000
# 2010-07-02 00:00:00-04:00    1.533333    1.540000    1.247333    1.280000
# 2010-07-06 00:00:00-04:00    1.333333    1.333333    1.055333    1.074000
# ...                               ...         ...         ...         ...
# 2024-12-02 00:00:00-05:00  352.380005  360.000000  351.149994  357.089996
# 2024-12-03 00:00:00-05:00  351.799988  355.690002  348.200012  351.420013
# 2024-12-04 00:00:00-05:00  353.000000  358.100006  348.600006  357.929993
# 2024-12-05 00:00:00-05:00  359.869995  375.429993  359.500000  369.489990
# 2024-12-06 00:00:00-05:00  377.269989  389.489990  370.799988  389.220001
#
#                               Volume    Tomorrow  Target
# Date
# 2010-06-29 00:00:00-04:00  281494500    1.588667       0
# 2010-06-30 00:00:00-04:00  257806500    1.464000       0
# 2010-07-01 00:00:00-04:00  123282000    1.280000       0
# 2010-07-02 00:00:00-04:00   77097000    1.074000       0
# 2010-07-06 00:00:00-04:00  103003500    1.053333       0
# ...                              ...         ...     ...
# 2024-12-02 00:00:00-05:00   77986500  351.420013       0
# 2024-12-03 00:00:00-05:00   58267200  357.929993       1
# 2024-12-04 00:00:00-05:00   50810900  369.489990       1
# 2024-12-05 00:00:00-05:00   81403600  389.220001       1
# 2024-12-06 00:00:00-05:00   78455915         NaN       0
#
# [3636 rows x 7 columns]

# %%
#Adding new predictors to the model. The SMA 5, 50, 200
from finta import TA
scopes = [5,50,200]
sma = 0 
new_predictors = []
new_predictors += ["Open", "High", "Low", "Close", "RSI"]

for scope in scopes:
#adding SMA column   
        SMA_scope = f'SMA_{scope}'

        sma = TA.SMA(stock, scope)
        stock[SMA_scope] = sma

#adding a column for the ratio close/sma
        ratio_column = f'Close_Ratio_{scope}'
        stock[ratio_column] = stock["Close"] / sma
  
#adding a column for RSI
        stock['RSI'] = TA.RSI(stock)
 

#Ading the trend as numbers of days that the stock went up over the scope 
        trend_column = f"Trend_{scope}"
        stock[trend_column] = stock.shift(1).rolling(scope).sum()["Target"]

#Adding the new predictors

        new_predictors += [SMA_scope, ratio_column, trend_column]
    


new_predictors
#stock.head(25)
# Out:
# ['Open',
#  'High',
#  'Low',
#  'Close',
#  'RSI',
#  'SMA_5',
#  'Close_Ratio_5',
#  'Trend_5',
#  'SMA_50',
#  'Close_Ratio_50',
#  'Trend_50',
#  'SMA_200',
#  'Close_Ratio_200',
#  'Trend_200']

# %%
#Cleaning the rows with N/A
stock = stock.dropna(subset=stock.columns[stock.columns != "Tomorrow"])
stock.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Tomorrow', 'Target', 'SMA_5',
#        'Close_Ratio_5', 'RSI', 'Trend_5', 'SMA_50', 'Close_Ratio_50',
#        'Trend_50', 'SMA_200', 'Close_Ratio_200', 'Trend_200'],
#       dtype='object')

# %%
#updating/tuning the model again
model = RandomForestClassifier(n_estimators=200, min_samples_split=50, random_state=1)

# %%
#changing the "predict" function to "predict_proba" to redefine what qualifies as 0 and 1 (UP or Down)
#that will descrease the number of days the stock is predicted to go up, but it will increase the probability of going UP
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict_proba(test[predictors])[:,1]
    preds[preds >=.55] = 1
    preds[preds <.55] = 0
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
#backtesting 
predictions = backtest(stock, model, new_predictors)
last_prediction_M2 = predictions['Predictions'].iloc[-1]
predictions
# Out:
#                            Target  Predictions
# Date
# 2021-03-22 00:00:00-04:00       0          0.0
# 2021-03-23 00:00:00-04:00       0          0.0
# 2021-03-24 00:00:00-04:00       1          0.0
# 2021-03-25 00:00:00-04:00       0          0.0
# 2021-03-26 00:00:00-04:00       0          1.0
# ...                           ...          ...
# 2024-12-02 00:00:00-05:00       0          0.0
# 2024-12-03 00:00:00-05:00       1          0.0
# 2024-12-04 00:00:00-05:00       1          0.0
# 2024-12-05 00:00:00-05:00       1          0.0
# 2024-12-06 00:00:00-05:00       0          0.0
#
# [936 rows x 2 columns]

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 1.0    485
# 0.0    451
# Name: count, dtype: int64

# %%
M2A = precision_score(predictions["Target"], predictions["Predictions"])
M2A
# Out:
# 0.5257731958762887

# %%
# Append the new row to the existing CSV file
model_accuracy.loc[len(model_accuracy)] = [ticker, M1A, last_prediction_M1,  M2A, last_prediction_M2]
model_accuracy.tail(1).to_csv('accuracy.csv', mode='a', header=False, index=False)

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.520299
# 0    0.479701
# Name: count, dtype: float64

# %%
print(f'The initail model has an accuracy of {M1A}. \nAfter the optimization the model has an accuracy of {M2A}')
# Out:
# The initail model has an accuracy of 0.5157232704402516.
# After the optimization the model has an accuracy of 0.5257731958762887
